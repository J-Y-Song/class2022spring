# %% [markdown]
# <a href="https://colab.research.google.com/github/J-Y-Song/class2022spring/blob/main/20220316.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 영어음성학응용 0309 파이썬 변수(int, float, str, list, tuple, dict)
# Programming language
# -	Language : words로 이루어져 있음 -> 변수
# -	Words: meaning과 content를 지니고 있음 -> assign
# -	Ex) word = content -> var = 3
# -	Syntax: words 를 조합하는 방식 (1) 조건문(if) (2) 반복문(for)
#
# 	변수 (모든 변수는 2종류로 분류가능)
# 1)	Numbers
# 2)	String
# *) list: 숫자 혹은 문자를 여러 개를 하나의 변수에 assign ex) var = [ , , ,]
# 	Print(a) : a 의 값을 출력 / print(type(a)): a의 type(int-정수형)이 출력 / 코드 마지막줄에서는 print 를 입력하지 않아도 print를 한 효과를 낼 수 있음
# -	Int: 정수형
# -	Float: 실수형 (소수점 사용)
# -	String: 문자형 (quote or double quote 사용)
# 	List의 index
# -	Print(a[1]) : a 의 1번째를 출력 (파이썬은 0번째부터 시작- 즉, 두번째 item을 출력)
# -	Print(a[1:3]) : a의 1번째부터 2번째를 출력 (콜론의 오른쪽은 미포함)
# -	Print(a[1:-1]): a의 1번째부터 마지막 수 하나를 제외하고 출력
# -	Print(a[1:]): a의 1번째부터 마지막까지를 출력
# -	Print(a[2][1]): a의 2번째 item(인덱스로 이루어진 아이템의 경우)의 1번째 아이템을 출력
# 	String의 index
# -	List의 index와 동일한 방법으로 진행
# -	Ex) a = ‘abcdef123’
# -	a[3:-1]: def12 출력
# 	tuple: list와 유사
# -	list 에서 사용하는 대괄호[ ] 대신 ( )소괄호 사용
# -	괄호 종류를 제외하고 모든 것이 동일 (access, 사칙연산 등은 가능)
# -	Tuple 은 변수를 assign 해서 수정하는 것이 불가 (개발자들이 실수로 변수를 지우는 것을 방지하는 목적으로 만들어진 것)
# -	Ex) a[1] =0 : a의 1번째 변수를 0으로 수정 -> list 에서는 가능/ tuple에서는 불가능
# 	Dict : dictionary의 준말
# -	a = { “a”: “apple”, “b” : “orange”, “c” :2014} (작은 따옴표, 큰 따옴표는 상관 x -> string의 표현)
# -	key: value 쌍으로 이루어진 아이템으로 구성됨 (위는 3개의 아이템)
# -	list 처럼 순서로 access를 하는 것이 아니라 key 값으로 access
# -	a[‘a’] : ‘apple’ 이 출력됨
#
# 영어음성학응용 0314 변수(list/str), 함수, syntax(반복문/조건문), list/dict comprehension
# [string]
# 	함수 사용 방법 : 함수문(input)
# -	Built-in function : import 할 필요없는 내장함수
# 	len: 길이를 나타내는 함수
# 	s.upper( ) : s를 대문자로 바꾸어주는 함수
# 	s.find(‘ ‘): #index of first instance of string ‘ ‘ inside s (-1 if not found)
# 	s = s.strip( ) # a copy of s without leading or trailing whitespace
# 	tokens = s.split(‘ ‘) # split s into a list wherever a ‘ ‘ is found (whitespace by default)
# 	s = ‘ ‘ . join(tokens) #combine the words of the text into a string using s as the glue
# 	s = s.replace(‘this’, ‘that’) #replace instances of this with that inside s
#
# [function]
# 	함수만들기: def함수명(입력변수1, 입력변수2):
# 함수정의에 대한 내용 기재 (ex. c = a + b)
# Return 출력변수
# 	내장함수보다 정의함수가 우위 -> 이름이 겹친다면 정의함수로 출력됨 (그런데 이렇게 하지말기)
#
# [syntax]
# 1)	반복문: for (while) (입력변수 사이사이 blank가 중요)
# 	For loop
#
# 	for i in range(4): i 에 0/1/2/3을 차례로 입력
# range는 list를 선언하는 함수 ( ex. range(4) = [0,1,2,3] )
# range(len(a)): a 의 길이만큼 index 를 선언
#
# 2)	조건문: if (switch)
# = 는 assign / == 같다
# If a == 0 : a 가 0이라면 print(a)
# If a != 0 : a가 0이 아니라면
#
# 	For의 중첩문
# range(1,3) = [1,2] / range(3,5) = [3,4]
#
# (1)	i에 1입력
# ((1)) j에 3 입력
# 1*3= 3
# ((2)) j에 4 입력
# 1*4=4
# (1)	i에 2입력
# ((1)) j에 3입력
# 2*3=6
# ((2)) j에 4입력
# 2*4=8
# 	list comprehension / dict comprehension(dict는 순서는 중요하지 않음)
# 	시험 출제
# -	List comprehension
#
#
# -	Dict comprehension
#
#
# 영어음성학응용 0316
# 	Import : 특정인이 이미 생성해 둔 package 를 사용하기 위해 불러오는 과정
# -	Ex. numpy : 구글에 검색하면 이미 생성이 되어 있음 (random number generating / 행렬 생성)
# -	보통은 많이 사용하는 package 들은 python을 설치하면 자동으로 install 되어 있음 -> import 만 하면 됨
# -	Built-in : import 할 필요 없음 (print / len)
# -	Import : 불러오기 쉽게 사용할 수 있도록 ram 메모리로 올리는 것
# -	Install : 파일 자체 설치 필요 – 현재 colab 은 구글 컴퓨터를 설치하고 있음 -> 대중적이지 않은 함수 사용 시 install 먼저 해야 함
# 	Import 방법
# (1)	Import numpy : numpy 불러오기
# -	불러오지 않으면 nameerror : name ‘numpy’ is not defined
# -	Import numpy as np : numpy 를 np 라는 이름으로 불러오기
# (2)	Numpy. Random. Randn(5) numpy 안에 randn 함수 불러오기
# N = np. Random.randn(100)
# 	Import. Matplotlib
# (1)	Import matplotlib : mean 을 0 standard deviation 을 1로 하는 그래프를 추출
# -	Import matplotlib. pyplot
# -	Import matplot. pyplot as plt
# -	From matplotlib import pyplot
# Pyplot. hist(n)
# -	From matplotlib. pyplot import hist
# 	From import 를 쓰면 import as 처럼 축약해서 부를 수 있는 효과
# Hist (n)
# (2)	Matplotlib(패키지이름). Pyplot(내부파일- 하위디렉토리 이름). Hist(n): 총 100개의 random number을 히스토그램하여라 (frequency 시각화)
# 	Numpy_matlablib
# (1)	Create nd arrays (n-dimensional array)
# -	Matrix 직사각형의 숫자배열
# -	X = np. Array ([1,2,3]) -> [1,2,3] 은 list -> list 를 array 로 변경한 상황
# [1,2,3]
# <class ‘numpy. ndarray’> 데이터 타입
# (3,) -> 3개의 item 이 들어있는 1차원 array
# -	X = np.arange(0,10,2) -> 0부터 2씩 증분해서 10이전까지
# -	X= np.linspace(0,10,6) -> 0부터 10 까지 6개의 자체적으로 등분한 숫자 출력
# -	양 끝 대괄호의 개수를 확인하면 array 의 차원을 확인가능
# (2)	Create random numbers : 난수 생성
# -	Np. Random. Normal (mean, standard deviation, size)
# -	X= np.random.normal(0,1,100) -> 정규분포 숫자 100개 1차원으로 random number array 생성
# -	플러팅: plt.hist (x, bins=10) -> 통(카테고리)을 10개 생성
# (3)	Generate a sine curve
# *radian: 각을 나타내는 또 다른 단위로, 원의 반지름에 대한 호의 길이의 비로 정의
# 180도 = 파이 radian, 360도 = 2*파이 radian, 90도 = 파이/2 radian
# -	Plt.figure () : 형태를 잡아주는 함수 (그래프를 그리는 함수)
# -	Theta1 = np.linspace (0, 2*np.pi, 100) -> 360 도까지 100개의 숫자로 등분
# -	S1 = np.sin(theta1)
# -	Theta2 = np.linspace (0, 2*np.pi, 100) + np.pi/2 -> 360+90 = 450도까지 100개의 숫자로 등분
# -	시험) Theta1 의 개수는 몇 개인가? 100개
# -	시험) s1에 존재하는 nd array 의 개수는 몇 개인가? 100개
# -	plt.subplot (2,1,1) # subplot: 그래프의 사이즈를 그래프만큼만 보여줌 # (rows, colums, panel number)
# 	그래프의 그림을 2x1의 형태로 그림
# -	plt.plot(theta1, s1, ‘.’) # (x값, y값, . 으로 그래프 그려라)
# (4)	correlation / coefficient
# -	1 <= r <= 1 : -1 반비례 / 1 정비례 / r의 절댓값이 1에 가까워짐: 상관관계 (correlation)이 높음
# -	S1 : 첫번째 그래프의 y 값 / s2: 두번째 그래프의 x 값
# -	Np. Corrcoef(s1, s2) : correlation 값 2.41915449 * e -17(10^-17)(=0) , 즉 0 -> 상관관계 없음
